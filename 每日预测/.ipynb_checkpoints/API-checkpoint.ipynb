# %%
import pandas as pd
import numpy as np
from functools import reduce
import datetime
from datetime import timedelta
import pymysql
from sqlalchemy import create_engine
# 导入模型
import xgboost as xgb

# %%
mysql_setting = {
        'host': '47.100.201.211',
        'port': 3306,
        'user': 'root',
        'passwd': 'iyGfLR64Ne4Ddhk7',
        # 数据库名称
        'db': 'data',
        'charset': 'utf8'
    }
engine = create_engine(
        "mysql+pymysql://{user}:{passwd}@{host}:{port}/{db}".format(
            **mysql_setting),
        max_overflow=5)

# %%
# sql = 'TRUNCATE TABLE predictAdvice'
# result = engine.execute(sql)
# table_name = 'predictAdvice'
# advice.to_sql(table_name, engine, if_exists='append', index=False)

# %% [markdown]
# # 接口

# %%
def predict(product, span):
    main = product
    # 通过sqlalchemy库连接mysql
    mysql_setting = {
            'host': '47.100.201.211',
            'port': 3306,
            'user': 'root',
            'passwd': 'iyGfLR64Ne4Ddhk7',
            # 数据库名称
            'db': 'data',
            'charset': 'utf8'
        }
    engine = create_engine("mysql+pymysql://{user}:{passwd}@{host}:{port}/{db}".format(**mysql_setting),max_overflow=5)
    # advice和relation表共用先获取
    sql_cmd = "select * from predictAdvice1"
    advice1 = pd.read_sql(sql_cmd, engine)
    sql_cmd = "select * from predictAdvice2"
    advice2 = pd.read_sql(sql_cmd, engine)
    sql_cmd = "select * from productRelation where product = %(product)s"
    relation = pd.read_sql(sql_cmd, engine, params={'product': product})
    # 首选农产品价格预测
    def mainPredict(product, span):
        # 判断是长期预测还是短期预测
        if span == 0:
            sql_cmd = "select * from predict_online_short where product = %(product)s"
            data_online = pd.read_sql(sql_cmd, engine, params={'product': product})
            sql_cmd = "select * from predict_offline_short where product = %(product)s"
            data_offline = pd.read_sql(sql_cmd, engine, params={'product': product})
        elif span == 1:
            sql_cmd = "select * from predict_online_long where product = %(product)s"
            data_online = pd.read_sql(sql_cmd, engine, params={'product': product})
            sql_cmd = "select * from predict_offline_long where product = %(product)s"
            data_offline = pd.read_sql(sql_cmd, engine, params={'product': product})
        price_predict = [] # 存放所有线上线下价格
    # 判断是否有线上价格和线下价格
        # 有线下价格
        if data_offline.empty and data_online.empty:
            return False
        if not data_offline.empty: 
            mainproduct = {}
            mainproduct["name"] = product
            mainproduct["online"] = 0
            # pricelist[{"date": , "predict price":}]
            df_offline = []
            df1 = data_offline.rename(columns={"price":"predict_price"})
            df2 = df1[["date", "predict_price"]].to_dict('index')
            for i in df2.values():
                df_offline.append(i)
            mainproduct["pricelist"] = df_offline
            price_predict.append(mainproduct)
            # 有线上价格
        if not data_online.empty: 
            mainproduct = {}
            mainproduct["name"] = product
            mainproduct["online"] = 1
            mainproduct["span"] = 0
            mainproduct["consumer_advice"] = advice1.loc[advice1['product']==product]['consumer advice'].values[0]
            # pricelist价格
            df_online = [] 
            df3 = data_online.rename(columns={"price":"predict_price"})
            df4 = df3[["date", "predict_price"]].to_dict('index')
            for i in df4.values():
                df_online.append(i)
            mainproduct["pricelist"] = df_online
            price_predict.append(mainproduct)
        return price_predict


    def predictOther(product, span):
        # 判断是长期预测还是短期预测
        if span == 0:
            sql_cmd = "select * from predict_online_short where product = %(product)s"
            data_online = pd.read_sql(sql_cmd, engine, params={'product': product})
            sql_cmd = "select * from predict_offline_short where product = %(product)s"
            data_offline = pd.read_sql(sql_cmd, engine, params={'product': product})
        elif span == 1:
            sql_cmd = "select * from predict_online_long where product = %(product)s"
            data_online = pd.read_sql(sql_cmd, engine, params={'product': product})
            sql_cmd = "select * from predict_offline_long where product = %(product)s"
            data_offline = pd.read_sql(sql_cmd, engine, params={'product': product})
        price_predict_other  = [] # 存放所有线上线下价格
        # 有线下价格
        if not data_offline.empty: 
            mainproduct = {}
            mainproduct["name"] = product
            mainproduct["online"] = 0
            mainproduct["span"] = 0
            df_offline = []
            df1 = data_offline.rename(columns={"price":"predict_price"})
            df2 = df1[["date", "predict_price"]].to_dict('index')
            for i in df2.values():
                df_offline.append(i)
            mainproduct["pricelist"] = df_offline
            price_predict_other.append(mainproduct)
            # 有线上价格
        if not data_online.empty: 
            mainproduct = {}
            mainproduct["name"] = product
            mainproduct["online"] = 1
            mainproduct["span"] = 0
            mainproduct["seller_advice"] = advice2.loc[(advice2['main']==main)&(advice2['cp']==product), 'seller advice'].values[0]
            # pricelist价格
            df_online = [] 
            df3 = data_online.rename(columns={"price":"predict_price"})
            df4 = df3[["date", "predict_price"]].to_dict('index')
            for i in df4.values():
                df_online.append(i)
            mainproduct["pricelist"] = df_online
            mainproduct
            price_predict_other.append(mainproduct)
        return price_predict_other    
    
    # 竞品（cp）价格预测
    def cpPredict(product, span):
        cp_price_predict = []
        # 获取竞品关系(先判断有无竞品)
        if relation["cpProduct"][0] is not None:
            cplist = [x for x in relation["cpProduct"][0].split()]
            for cpProduct in cplist:
                for i in predictOther(cpProduct, span):
                    cp_price_predict.append(i)
        return cp_price_predict
    # 替代品（sub）价格预测
    def subPredict(product, span):
        sub_price_predict = []
        # 获取替代品关系(先判断有无替代品)
        if relation["subProduct"][0] is not None:
            sublist = [x for x in relation["subProduct"][0].split()]
            for subProduct in sublist:
                for i in predictOther(subProduct, span):
                    sub_price_predict.append(i)
        return sub_price_predict
    def getPrice(product, span):
        data = {}
        data["price_predict"] = []
        data["cp_price_predict"] = []
        data["sub_price_predict"] = []
        for i in mainPredict(product, span):
            data["price_predict"].append(i)
        for i in cpPredict(product, span):
            data["cp_price_predict"].append(i)
        for i in subPredict(product, span):
            data["sub_price_predict"].append(i)
        return data
    return getPrice(product, span)

# %%
def comparePrice(product, start, end):
    # 通过sqlalchemy库连接mysql
    mysql_setting = {
            'host': '47.100.201.211',
            'port': 3306,
            'user': 'root',
            'passwd': 'iyGfLR64Ne4Ddhk7',
            # 数据库名称
            'db': 'data',
            'charset': 'utf8'
        }
    engine = create_engine("mysql+pymysql://{user}:{passwd}@{host}:{port}/{db}".format(**mysql_setting),max_overflow=5)
    sql_cmd = "select * from productRelation where product = %(product)s"
    relation = pd.read_sql(sql_cmd, engine, params={'product': product})
    def mainCompare(product):
        df_all = []
        main_product_compare = {}
        main_product_compare['name'] = product
        main_product_compare['span'] = 0
        sql_cmd = "select * from price_real_predict_compare_short where product = %(product)s and date >= %(start)s and date <= %(end)s"
        dt = pd.read_sql(sql_cmd, engine, params={'product': product, 'start':start, 'end':end})
        dt = dt.fillna('')
        df_online = [] 
        dt1 = dt[["date", "real_price", "predict_price"]].to_dict('index')
        for i in dt1.values():
            df_online.append(i)
        main_product_compare["pricelist"] = df_online
        df_all.append(main_product_compare)
        return df_all
    def cpCompare(product):
        cp_product_compare = []
        # 获取竞品关系(先判断有无竞品)
        if relation["cpProduct"][0] is not None:
            cplist = [x for x in relation["cpProduct"][0].split()]
            for cpProduct in cplist:
                for i in mainCompare(cpProduct):
                    cp_product_compare.append(i)
        return cp_product_compare
    def getAll(product):
        data = {}
        data["main_product_compare"] = []
        data["cp_product_compare"] = []
        for i in mainCompare(product):
            data["main_product_compare"].append(i)
        for i in cpCompare(product):
            data["cp_product_compare"].append(i)
        return data
    return getAll(product)

# %%
comparePrice('巢湖中垾番茄', '2022-07-15', '2022-08-15')
# Out:
# {'main_product_compare': [{'name': '巢湖中垾番茄',
#    'span': 0,
#    'pricelist': [{'date': datetime.date(2022, 7, 15),
#      'real_price': 9.93,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 7, 16),
#      'real_price': 9.93,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 7, 17),
#      'real_price': 9.93,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 7, 18),
#      'real_price': 9.93,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 7, 19),
#      'real_price': 9.93,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 7, 20),
#      'real_price': 9.93,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 7, 21),
#      'real_price': 9.93,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 7, 22),
#      'real_price': 9.93,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 7, 23),
#      'real_price': 9.93,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 7, 24),
#      'real_price': 9.93,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 7, 25),
#      'real_price': 9.93,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 7, 26),
#      'real_price': 9.93,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 7, 27),
#      'real_price': 9.93,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 7, 28),
#      'real_price': 9.93,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 7, 29),
#      'real_price': 9.93,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 7, 30),
#      'real_price': 9.93,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 7, 31),
#      'real_price': 9.93,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 8, 1),
#      'real_price': 9.93,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 8, 2),
#      'real_price': 9.93,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 8, 3),
#      'real_price': 9.93,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 8, 4),
#      'real_price': 9.93,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 8, 5),
#      'real_price': 9.93,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 8, 6),
#      'real_price': 9.93,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 8, 7),
#      'real_price': 9.93,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 8, 8),
#      'real_price': 9.93,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 8, 9),
#      'real_price': 9.93,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 8, 10),
#      'real_price': 9.93,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 8, 11),
#      'real_price': 9.93,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 8, 12),
#      'real_price': 9.93,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 8, 13),
#      'real_price': 9.93,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 8, 14),
#      'real_price': 9.93,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 8, 15),
#      'real_price': 9.93,
#      'predict_price': 9.93}]}],
#  'cp_product_compare': [{'name': '陕西泾阳普罗旺斯番茄',
#    'span': 0,
#    'pricelist': [{'date': datetime.date(2022, 7, 15),
#      'real_price': 9.96,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 7, 16),
#      'real_price': 9.96,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 7, 17),
#      'real_price': 9.96,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 7, 18),
#      'real_price': 9.96,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 7, 19),
#      'real_price': 9.96,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 7, 20),
#      'real_price': 9.96,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 7, 21),
#      'real_price': 9.96,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 7, 22),
#      'real_price': 9.9,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 7, 23),
#      'real_price': 9.85,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 7, 24),
#      'real_price': 9.8,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 7, 25),
#      'real_price': 9.74,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 7, 26),
#      'real_price': 9.96,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 7, 27),
#      'real_price': 9.96,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 7, 28),
#      'real_price': 9.96,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 7, 29),
#      'real_price': 9.96,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 7, 30),
#      'real_price': 9.74,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 7, 31),
#      'real_price': 9.96,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 8, 1),
#      'real_price': 9.96,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 8, 2),
#      'real_price': 9.96,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 8, 3),
#      'real_price': 9.96,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 8, 4),
#      'real_price': 9.96,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 8, 5),
#      'real_price': 9.96,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 8, 6),
#      'real_price': 9.96,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 8, 7),
#      'real_price': 9.96,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 8, 8),
#      'real_price': 9.96,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 8, 9),
#      'real_price': 9.96,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 8, 10),
#      'real_price': 9.96,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 8, 11),
#      'real_price': 9.96,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 8, 12),
#      'real_price': 9.96,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 8, 13),
#      'real_price': 9.96,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 8, 14),
#      'real_price': 9.96,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 8, 15),
#      'real_price': 9.96,
#      'predict_price': 9.96}]},
#   {'name': '新疆吐鲁番普罗旺斯番茄',
#    'span': 0,
#    'pricelist': [{'date': datetime.date(2022, 7, 15),
#      'real_price': 9.98,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 7, 16),
#      'real_price': 9.98,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 7, 17),
#      'real_price': 9.98,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 7, 18),
#      'real_price': 9.98,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 7, 19),
#      'real_price': 9.98,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 7, 20),
#      'real_price': 9.98,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 7, 21),
#      'real_price': 9.98,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 7, 22),
#      'real_price': 9.98,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 7, 23),
#      'real_price': 9.98,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 7, 24),
#      'real_price': 9.98,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 7, 25),
#      'real_price': 9.98,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 7, 26),
#      'real_price': 9.98,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 7, 27),
#      'real_price': 9.98,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 7, 28),
#      'real_price': 9.98,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 7, 29),
#      'real_price': 9.98,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 7, 30),
#      'real_price': 9.98,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 7, 31),
#      'real_price': 9.98,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 8, 1),
#      'real_price': 7.98,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 8, 2),
#      'real_price': 7.98,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 8, 3),
#      'real_price': 7.98,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 8, 4),
#      'real_price': 7.98,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 8, 5),
#      'real_price': 7.98,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 8, 6),
#      'real_price': 7.98,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 8, 7),
#      'real_price': 7.98,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 8, 8),
#      'real_price': 7.98,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 8, 9),
#      'real_price': 7.98,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 8, 10),
#      'real_price': 7.98,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 8, 11),
#      'real_price': 7.98,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 8, 12),
#      'real_price': 7.98,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 8, 13),
#      'real_price': 7.98,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 8, 14),
#      'real_price': 7.98,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 8, 15),
#      'real_price': 7.98,
#      'predict_price': 7.98}]},
#   {'name': '山东普罗旺斯西红柿',
#    'span': 0,
#    'pricelist': [{'date': datetime.date(2022, 7, 15),
#      'real_price': 14.8,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 7, 16),
#      'real_price': 14.8,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 7, 17),
#      'real_price': 14.8,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 7, 18),
#      'real_price': 14.8,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 7, 19),
#      'real_price': 14.8,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 7, 20),
#      'real_price': 14.8,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 7, 21),
#      'real_price': 14.8,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 7, 22),
#      'real_price': 14.8,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 7, 23),
#      'real_price': 14.8,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 7, 24),
#      'real_price': 14.8,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 7, 25),
#      'real_price': 14.8,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 7, 26),
#      'real_price': 14.8,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 7, 27),
#      'real_price': 14.8,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 7, 28),
#      'real_price': 14.8,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 7, 29),
#      'real_price': 14.8,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 7, 30),
#      'real_price': 14.8,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 7, 31),
#      'real_price': 14.8,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 8, 1),
#      'real_price': 14.8,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 8, 2),
#      'real_price': 14.8,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 8, 3),
#      'real_price': 14.8,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 8, 4),
#      'real_price': 14.8,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 8, 5),
#      'real_price': 14.8,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 8, 6),
#      'real_price': 14.8,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 8, 7),
#      'real_price': 14.8,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 8, 8),
#      'real_price': 14.8,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 8, 9),
#      'real_price': 14.8,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 8, 10),
#      'real_price': 14.8,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 8, 11),
#      'real_price': 14.8,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 8, 12),
#      'real_price': 14.8,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 8, 13),
#      'real_price': 14.8,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 8, 14),
#      'real_price': 14.8,
#      'predict_price': ''},
#     {'date': datetime.date(2022, 8, 15),
#      'real_price': 14.8,
#      'predict_price': 14.8}]}]}

# %%
predict('仙桃香米', 0)
# Out:
# {'price_predict': [{'name': '仙桃香米',
#    'online': 1,
#    'span': 0,
#    'consumer_advice': '湖北仙桃洪茂春春红米是湖北省仙桃市特产，具有“鲜、香、弹”特点。米粒纤细莹润颗粒饱满透亮，米饭清香四溢，回味悠长，粒粒清晰有嚼劲，软糯Q弹。栽种地日照雨水充足，土壤肥沃，气候地理位置俱佳，天然雨露，高山活水灌溉，细心的管理与呵护，逐渐演化出与众不同的味道和丰富的营养价值。上市后的大米储存周期一般为6-12个月，在潮湿的地区储存时间更短，且储存时间过长大米营养会逐渐流失，口感会变差，因此建议不要储存超过3个月。预测未来一周湖北仙桃洪茂春春红米将会降低，因此对湖北仙桃洪茂春春红米有需求的消费者若不急于购买大米，可于一周后购买约1-3个月的量。',
#    'pricelist': [{'date': datetime.date(2022, 8, 12), 'predict_price': 4.8},
#     {'date': datetime.date(2022, 8, 13), 'predict_price': 4.8},
#     {'date': datetime.date(2022, 8, 14), 'predict_price': 4.8},
#     {'date': datetime.date(2022, 8, 15), 'predict_price': 4.8},
#     {'date': datetime.date(2022, 8, 16), 'predict_price': 4.8},
#     {'date': datetime.date(2022, 8, 17), 'predict_price': 4.8},
#     {'date': datetime.date(2022, 8, 18), 'predict_price': 4.8},
#     {'date': datetime.date(2022, 8, 19), 'predict_price': 4.8},
#     {'date': datetime.date(2022, 8, 20), 'predict_price': 4.8},
#     {'date': datetime.date(2022, 8, 21), 'predict_price': 4.8},
#     {'date': datetime.date(2022, 8, 22), 'predict_price': 4.8},
#     {'date': datetime.date(2022, 8, 23), 'predict_price': 4.8},
#     {'date': datetime.date(2022, 8, 24), 'predict_price': 4.8},
#     {'date': datetime.date(2022, 8, 25), 'predict_price': 4.8},
#     {'date': datetime.date(2022, 8, 26), 'predict_price': 4.8}]}],
#  'cp_price_predict': [{'name': '万年贡蟹田丝苗米',
#    'online': 1,
#    'span': 0,
#    'seller_advice': '湖北仙桃洪茂春春红米在电商平台的竞争品主要来自江西省宜春市奉新县以及黑龙江省五常市、江西省井冈山市等地。若产量和库存允许，近期可以采取措施为产品获取更多电商平台流量，比如优化商品名称以提高自然搜索流量、利用淘宝直通车和电商平台官方活动（店内活动、淘宝直播等）和站外活动（如社群运营活动）进行推广引流，争取在短期内提高销量。同时密切关注行业最新动向，注意控制成本（种植成本、供应链成本等）。',
#    'pricelist': [{'date': datetime.date(2022, 8, 12), 'predict_price': 4.99},
#     {'date': datetime.date(2022, 8, 13), 'predict_price': 4.99},
#     {'date': datetime.date(2022, 8, 14), 'predict_price': 4.69},
#     {'date': datetime.date(2022, 8, 15), 'predict_price': 4.99},
#     {'date': datetime.date(2022, 8, 16), 'predict_price': 4.99},
#     {'date': datetime.date(2022, 8, 17), 'predict_price': 4.69},
#     {'date': datetime.date(2022, 8, 18), 'predict_price': 4.99},
#     {'date': datetime.date(2022, 8, 19), 'predict_price': 4.99},
#     {'date': datetime.date(2022, 8, 20), 'predict_price': 4.99},
#     {'date': datetime.date(2022, 8, 21), 'predict_price': 4.99},
#     {'date': datetime.date(2022, 8, 22), 'predict_price': 4.69},
#     {'date': datetime.date(2022, 8, 23), 'predict_price': 4.99},
#     {'date': datetime.date(2022, 8, 24), 'predict_price': 4.69},
#     {'date': datetime.date(2022, 8, 25), 'predict_price': 4.99},
#     {'date': datetime.date(2022, 8, 26), 'predict_price': 4.99}]},
#   {'name': '巢湖稻虾米',
#    'online': 1,
#    'span': 0,
#    'seller_advice': '湖北仙桃洪茂春春红米在电商平台的竞争品主要来自江西省宜春市奉新县以及黑龙江省五常市、江西省井冈山市等地。若产量和库存允许，近期可以采取措施为产品获取更多电商平台流量，比如优化商品名称以提高自然搜索流量、利用淘宝直通车和电商平台官方活动（店内活动、淘宝直播等）和站外活动（如社群运营活动）进行推广引流，争取在短期内提高销量。同时密切关注行业最新动向，注意控制成本（种植成本、供应链成本等）。',
#    'pricelist': [{'date': datetime.date(2022, 8, 12), 'predict_price': 4.5},
#     {'date': datetime.date(2022, 8, 13), 'predict_price': 4.5},
#     {'date': datetime.date(2022, 8, 14), 'predict_price': 4.5},
#     {'date': datetime.date(2022, 8, 15), 'predict_price': 4.5},
#     {'date': datetime.date(2022, 8, 16), 'predict_price': 4.5},
#     {'date': datetime.date(2022, 8, 17), 'predict_price': 4.5},
#     {'date': datetime.date(2022, 8, 18), 'predict_price': 4.5},
#     {'date': datetime.date(2022, 8, 19), 'predict_price': 4.5},
#     {'date': datetime.date(2022, 8, 20), 'predict_price': 4.5},
#     {'date': datetime.date(2022, 8, 21), 'predict_price': 4.5},
#     {'date': datetime.date(2022, 8, 22), 'predict_price': 4.5},
#     {'date': datetime.date(2022, 8, 23), 'predict_price': 4.5},
#     {'date': datetime.date(2022, 8, 24), 'predict_price': 4.5},
#     {'date': datetime.date(2022, 8, 25), 'predict_price': 4.5},
#     {'date': datetime.date(2022, 8, 26), 'predict_price': 4.5}]},
#   {'name': '黑龙江五常大米',
#    'online': 1,
#    'span': 0,
#    'seller_advice': '湖北仙桃洪茂春春红米在电商平台的竞争品主要来自江西省宜春市奉新县以及黑龙江省五常市、江西省井冈山市等地。若产量和库存允许，近期可以采取措施为产品获取更多电商平台流量，比如优化商品名称以提高自然搜索流量、利用淘宝直通车和电商平台官方活动（店内活动、淘宝直播等）和站外活动（如社群运营活动）进行推广引流，争取在短期内提高销量。同时密切关注行业最新动向，注意控制成本（种植成本、供应链成本等）。',
#    'pricelist': [{'date': datetime.date(2022, 8, 12), 'predict_price': 9.9},
#     {'date': datetime.date(2022, 8, 13), 'predict_price': 9.9},
#     {'date': datetime.date(2022, 8, 14), 'predict_price': 9.9},
#     {'date': datetime.date(2022, 8, 15), 'predict_price': 9.9},
#     {'date': datetime.date(2022, 8, 16), 'predict_price': 8.99},
#     {'date': datetime.date(2022, 8, 17), 'predict_price': 9.9},
#     {'date': datetime.date(2022, 8, 18), 'predict_price': 9.9},
#     {'date': datetime.date(2022, 8, 19), 'predict_price': 8.99},
#     {'date': datetime.date(2022, 8, 20), 'predict_price': 9.9},
#     {'date': datetime.date(2022, 8, 21), 'predict_price': 9.9},
#     {'date': datetime.date(2022, 8, 22), 'predict_price': 8.99},
#     {'date': datetime.date(2022, 8, 23), 'predict_price': 8.99},
#     {'date': datetime.date(2022, 8, 24), 'predict_price': 9.9},
#     {'date': datetime.date(2022, 8, 25), 'predict_price': 8.99},
#     {'date': datetime.date(2022, 8, 26), 'predict_price': 9.9}]},
#   {'name': '金龙鱼苏北大米',
#    'online': 1,
#    'span': 0,
#    'seller_advice': '湖北仙桃洪茂春春红米在电商平台的竞争品主要来自江西省宜春市奉新县以及黑龙江省五常市、江西省井冈山市等地。在成本可控、利润可接受的情况下，可于近期参与电商平台的促销活动（如秒杀、会员专享价、品类活动日等），在获取电商平台流量加持的同时跟随竞品价格，保持价格竞争力。',
#    'pricelist': [{'date': datetime.date(2022, 8, 12), 'predict_price': 2.78},
#     {'date': datetime.date(2022, 8, 13), 'predict_price': 2.99},
#     {'date': datetime.date(2022, 8, 14), 'predict_price': 2.99},
#     {'date': datetime.date(2022, 8, 15), 'predict_price': 2.99},
#     {'date': datetime.date(2022, 8, 16), 'predict_price': 2.99},
#     {'date': datetime.date(2022, 8, 17), 'predict_price': 2.99},
#     {'date': datetime.date(2022, 8, 18), 'predict_price': 2.99},
#     {'date': datetime.date(2022, 8, 19), 'predict_price': 2.99},
#     {'date': datetime.date(2022, 8, 20), 'predict_price': 2.99},
#     {'date': datetime.date(2022, 8, 21), 'predict_price': 2.78},
#     {'date': datetime.date(2022, 8, 22), 'predict_price': 2.78},
#     {'date': datetime.date(2022, 8, 23), 'predict_price': 2.78},
#     {'date': datetime.date(2022, 8, 24), 'predict_price': 2.99},
#     {'date': datetime.date(2022, 8, 25), 'predict_price': 2.99},
#     {'date': datetime.date(2022, 8, 26), 'predict_price': 2.69}]}],
#  'sub_price_predict': []}

# %%
sql_cmd = "select * from price_real_predict_compare_short where product = %(product)s and date >= %(start)s and date <= %(end)s"
dt = pd.read_sql(sql_cmd, engine, params={'product': '巢湖稻虾米', 'start':'2022-07-30', 'end': '2022-08-16'})

# %%
dt
# Out:
#    product        date  real_price  predict_price
# 0    巢湖稻虾米  2022-07-30         4.5            NaN
# 1    巢湖稻虾米  2022-07-31         4.5            NaN
# 2    巢湖稻虾米  2022-08-01         4.5            NaN
# 3    巢湖稻虾米  2022-08-02         4.5            NaN
# 4    巢湖稻虾米  2022-08-03         4.5            NaN
# 5    巢湖稻虾米  2022-08-04         4.5            NaN
# 6    巢湖稻虾米  2022-08-05         4.5            NaN
# 7    巢湖稻虾米  2022-08-06         4.5            NaN
# 8    巢湖稻虾米  2022-08-07         4.5            NaN
# 9    巢湖稻虾米  2022-08-08         4.5            NaN
# 10   巢湖稻虾米  2022-08-09         4.5            NaN
# 11   巢湖稻虾米  2022-08-10         4.5            NaN
# 12   巢湖稻虾米  2022-08-11         4.5            NaN
# 13   巢湖稻虾米  2022-08-12         4.5            NaN
# 14   巢湖稻虾米  2022-08-13         4.5            NaN
# 15   巢湖稻虾米  2022-08-14         4.5            NaN
# 16   巢湖稻虾米  2022-08-15         4.5            4.5
# 17   巢湖稻虾米  2022-08-16         4.5            4.5

# %% [markdown]
# # new advice

# %%
# riseAdvice = pd.read_csv('rise.csv', encoding='utf=8')
# reduceAdvice = pd.read_csv('reduce.csv', encoding='utf=8')
# sellerAdvice = pd.read_csv('sellerAdvice.csv', encoding='utf=8')

# %%
# result1 = engine.execute('TRUNCATE TABLE riseAdvice')
# result2 = engine.execute('TRUNCATE TABLE reduceAdvice')
# result3 = engine.execute('TRUNCATE TABLE sellerAdvice')
# riseAdvice.to_sql('riseAdvice', engine, if_exists='append', index=False)
# reduceAdvice.to_sql('reduceAdvice', engine, if_exists='append', index=False)
# sellerAdvice.to_sql('sellerAdvice', engine, if_exists='append', index=False)

# %%
#根据索引分组计算
# group1 = predict_online_short.groupby('product').agg({
#     'price':get_price_trend
# })
# group4 = predict_online_long.groupby('product').agg({
#     'price':get_price_trend
# })
# group3.rename(columns={'price': 'advice_short'}, inplace=True)
# group4.rename(columns={'price': 'advice_long'}, inplace=True)
# group = pd.merge(group3, group4, on='product', how='left')
# advice = pd.merge(advice_online, group, on='product', how='left')
